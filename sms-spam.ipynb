# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maya rai\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\maya rai\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\Users\Maya Rai\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("./sms-spam(in).csv")

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.columns
# Out:
# Index(['v1', 'v2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],inplace=True)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.rename(columns={'v1':'result','v2':'input'},inplace=True)

# %%
df.head()
# Out:
#   result                                              input
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['result']
# Out:
# 0        ham
# 1        ham
# 2       spam
# 3        ham
# 4        ham
#         ...
# 5567    spam
# 5568     ham
# 5569     ham
# 5570     ham
# 5571     ham
# Name: result, Length: 5572, dtype: object

# %%
df['result'].value_counts()
# Out:
# result
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#       result  input
# 0      False  False
# 1      False  False
# 2      False  False
# 3      False  False
# 4      False  False
# ...      ...    ...
# 5567   False  False
# 5568   False  False
# 5569   False  False
# 5570   False  False
# 5571   False  False
#
# [5572 rows x 2 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
df.shape
# Out:
# (5572, 2)

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# %pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: matplotlib in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (3.10.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\maya rai\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in c:\users\maya rai\appdata\roaming\python\python310\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: pillow>=8 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\maya rai\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\Users\Maya Rai\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt
plt.pie(df['result'].value_counts(),labels=['Not Spam','Spam'],autopct='%0.2f')
plt.show()

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (3.9.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: regex>=2021.8.3 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: click in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: colorama in c:\users\maya rai\appdata\roaming\python\python310\site-packages (from click->nltk) (0.4.6)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\Users\Maya Rai\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package moses_sample to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\Maya Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to C:\Users\Maya
# [nltk_data]    |     Rai\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
df=df.replace({"ham":0,"spam":1})
# Out:
# C:\Users\Maya Rai\AppData\Local\Temp\ipykernel_26912\784764192.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df=df.replace({"ham":0,"spam":1})

# %%
df.head()
# Out:
#    result                                              input
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Maya
# [nltk_data]     Rai\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwords=stopwords.words("English")
def transform_text (text):
    useful_words=[]
    text = text.lower()
    words = nltk.word_tokenize(text)
    removedSC = list()
    for word in words:
        if word  not in stopwords:
            useful_words.append(word)
    return " ".join(useful_words)

# %%
transform_text("hsdfhsg Im Ananya")
# Out:
# 'hsdfhsg im ananya'

# %%
df['processed'] = df['input'].apply(transform_text)

# %%
df.head()
# Out:
#    result                                              input  \
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...
#
#                                            processed
# 0  go jurong point , crazy .. available bugis n g...
# 1                    ok lar ... joking wif u oni ...
# 2  free entry 2 wkly comp win fa cup final tkts 2...
# 3        u dun say early hor ... u c already say ...
# 4       nah n't think goes usf , lives around though

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Maya
# [nltk_data]     Rai\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
spamWords = list()

for msg in df[df['result'] == 1]['processed'].tolist():
  for word in msg.split():
    spamWords.append(word)
spamWords
# Out:
# ['free',
#  'entry',
#  '2',
#  'wkly',
#  'comp',
#  'win',
#  'fa',
#  'cup',
#  'final',
#  'tkts',
#  '21st',
#  'may',
#  '2005.',
#  'text',
#  'fa',
#  '87121',
#  'receive',
#  'entry',
#  'question',
#  '(',
#  'std',
#  'txt',
#  'rate',
#  ')',
#  '&',
#  'c',
#  "'s",
#  'apply',
#  '08452810075over18',
#  "'s",
#  'freemsg',
#  'hey',
#  'darling',
#  "'s",
#  '3',
#  'week',
#  "'s",
#  'word',
#  'back',
#  '!',
#  "'d",
#  'like',
#  'fun',
#  'still',
#  '?',
#  'tb',
#  'ok',
#  '!',
#  'xxx',
#  'std',
#  'chgs',
#  'send',
#  ',',
#  'å£1.50',
#  'rcv',
#  'winner',
#  '!',
#  '!',
#  'valued',
#  'network',
#  'customer',
#  'selected',
#  'receivea',
#  'å£900',
#  'prize',
#  'reward',
#  '!',
#  'claim',
#  'call',
#  '09061701461.',
#  'claim',
#  'code',
#  'kl341',
#  '.',
#  'valid',
#  '12',
#  'hours',
#  '.',
#  'mobile',
#  '11',
#  'months',
#  '?',
#  'u',
#  'r',
#  'entitled',
#  'update',
#  'latest',
#  'colour',
#  'mobiles',
#  'camera',
#  'free',
#  '!',
#  'call',
#  'mobile',
#  'update',
#  'co',
#  'free',
#  '08002986030',
#  'six',
#  'chances',
#  'win',
#  'cash',
#  '!',
#  '100',
#  '20,000',
#  'pounds',
#  'txt',
#  '>',
#  'csh11',
#  'send',
#  '87575.',
#  'cost',
#  '150p/day',
#  ',',
#  '6days',
#  ',',
#  '16+',
#  'tsandcs',
#  'apply',
#  'reply',
#  'hl',
#  '4',
#  'info',
#  'urgent',
#  '!',
#  '1',
#  'week',
#  'free',
#  'membership',
#  'å£100,000',
#  'prize',
#  'jackpot',
#  '!',
#  'txt',
#  'word',
#  ':',
#  'claim',
#  ':',
#  '81010',
#  '&',
#  'c',
#  'www.dbuk.net',
#  'lccltd',
#  'pobox',
#  '4403ldnw1a7rw18',
#  'xxxmobilemovieclub',
#  ':',
#  'use',
#  'credit',
#  ',',
#  'click',
#  'wap',
#  'link',
#  'next',
#  'txt',
#  'message',
#  'click',
#  '>',
#  '>',
#  'http',
#  ':',
#  '//wap',
#  '.',
#  'xxxmobilemovieclub.com',
#  '?',
#  'n=qjkgighjjgcbl',
#  'england',
#  'v',
#  'macedonia',
#  '-',
#  'dont',
#  'miss',
#  'goals/team',
#  'news',
#  '.',
#  'txt',
#  'ur',
#  'national',
#  'team',
#  '87077',
#  'eg',
#  'england',
#  '87077',
#  'try',
#  ':',
#  'wales',
#  ',',
#  'scotland',
#  '4txt/ì¼1.20',
#  'poboxox36504w45wq',
#  '16+',
#  'thanks',
#  'subscription',
#  'ringtone',
#  'uk',
#  'mobile',
#  'charged',
#  'å£5/month',
#  'please',
#  'confirm',
#  'replying',
#  'yes',
#  '.',
#  'reply',
#  'charged',
#  '07732584351',
#  '-',
#  'rodger',
#  'burns',
#  '-',
#  'msg',
#  '=',
#  'tried',
#  'call',
#  'reply',
#  'sms',
#  'free',
#  'nokia',
#  'mobile',
#  '+',
#  'free',
#  'camcorder',
#  '.',
#  'please',
#  'call',
#  '08000930705',
#  'delivery',
#  'tomorrow',
#  'sms',
#  '.',
#  'ac',
#  'sptv',
#  ':',
#  'new',
#  'jersey',
#  'devils',
#  'detroit',
#  'red',
#  'wings',
#  'play',
#  'ice',
#  'hockey',
#  '.',
#  'correct',
#  'incorrect',
#  '?',
#  'end',
#  '?',
#  'reply',
#  'end',
#  'sptv',
#  'congrats',
#  '!',
#  '1',
#  'year',
#  'special',
#  'cinema',
#  'pass',
#  '2',
#  '.',
#  'call',
#  '09061209465',
#  '!',
#  'c',
#  'suprman',
#  'v',
#  ',',
#  'matrix3',
#  ',',
#  'starwars3',
#  ',',
#  'etc',
#  '4',
#  'free',
#  '!',
#  'bx420-ip4-5we',
#  '.',
#  '150pm',
#  '.',
#  'dont',
#  'miss',
#  '!',
#  'valued',
#  'customer',
#  ',',
#  'pleased',
#  'advise',
#  'following',
#  'recent',
#  'review',
#  'mob',
#  '.',
#  'awarded',
#  'å£1500',
#  'bonus',
#  'prize',
#  ',',
#  'call',
#  '09066364589',
#  'urgent',
#  'ur',
#  'awarded',
#  'complimentary',
#  'trip',
#  'eurodisinc',
#  'trav',
#  ',',
#  'aco',
#  '&',
#  'entry41',
#  'å£1000',
#  '.',
#  'claim',
#  'txt',
#  'dis',
#  '87121',
#  '18+6',
#  '*',
#  'å£1.50',
#  '(',
#  'morefrmmob',
#  '.',
#  'shracomorsglsuplt',
#  ')',
#  '10',
#  ',',
#  'ls1',
#  '3aj',
#  'hear',
#  'new',
#  '\\divorce',
#  'barbie\\',
#  "''",
#  '?',
#  'comes',
#  'ken',
#  "'s",
#  'stuff',
#  '!',
#  "''",
#  'please',
#  'call',
#  'customer',
#  'service',
#  'representative',
#  '0800',
#  '169',
#  '6031',
#  '10am-9pm',
#  'guaranteed',
#  'å£1000',
#  'cash',
#  'å£5000',
#  'prize',
#  '!',
#  'free',
#  'ringtone',
#  'waiting',
#  'collected',
#  '.',
#  'simply',
#  'text',
#  'password',
#  '\\mix\\',
#  "''",
#  '85069',
#  'verify',
#  '.',
#  'get',
#  'usher',
#  'britney',
#  '.',
#  'fml',
#  'gent',
#  '!',
#  'trying',
#  'contact',
#  '.',
#  'last',
#  'weekends',
#  'draw',
#  'shows',
#  'å£1000',
#  'prize',
#  'guaranteed',
#  '.',
#  'call',
#  '09064012160.',
#  'claim',
#  'code',
#  'k52',
#  '.',
#  'valid',
#  '12hrs',
#  '.',
#  '150ppm',
#  'winner',
#  'u',
#  'specially',
#  'selected',
#  '2',
#  'receive',
#  'å£1000',
#  '4',
#  '*',
#  'holiday',
#  '(',
#  'flights',
#  'inc',
#  ')',
#  'speak',
#  'live',
#  'operator',
#  '2',
#  'claim',
#  '0871277810910p/min',
#  '(',
#  '18+',
#  ')',
#  'private',
#  '!',
#  '2004',
#  'account',
#  'statement',
#  '07742676969',
#  'shows',
#  '786',
#  'unredeemed',
#  'bonus',
#  'points',
#  '.',
#  'claim',
#  'call',
#  '08719180248',
#  'identifier',
#  'code',
#  ':',
#  '45239',
#  'expires',
#  'urgent',
#  '!',
#  'mobile',
#  '.',
#  'awarded',
#  'å£2000',
#  'bonus',
#  'caller',
#  'prize',
#  '5/9/03',
#  'final',
#  'try',
#  'contact',
#  'u',
#  '!',
#  'call',
#  'landline',
#  '09064019788',
#  'box42wr29c',
#  ',',
#  '150ppm',
#  'todays',
#  'voda',
#  'numbers',
#  'ending',
#  '7548',
#  'selected',
#  'receive',
#  '$',
#  '350',
#  'award',
#  '.',
#  'match',
#  'please',
#  'call',
#  '08712300220',
#  'quoting',
#  'claim',
#  'code',
#  '4041',
#  'standard',
#  'rates',
#  'app',
#  'sunshine',
#  'quiz',
#  'wkly',
#  'q',
#  '!',
#  'win',
#  'top',
#  'sony',
#  'dvd',
#  'player',
#  'u',
#  'know',
#  'country',
#  'algarve',
#  '?',
#  'txt',
#  'ansr',
#  '82277.',
#  'å£1.50',
#  'sp',
#  ':',
#  'tyrone',
#  'want',
#  '2',
#  'get',
#  'laid',
#  'tonight',
#  '?',
#  'want',
#  'real',
#  'dogging',
#  'locations',
#  'sent',
#  'direct',
#  '2',
#  'ur',
#  'mob',
#  '?',
#  'join',
#  'uk',
#  "'s",
#  'largest',
#  'dogging',
#  'network',
#  'bt',
#  'txting',
#  'gravel',
#  '69888',
#  '!',
#  'nt',
#  '.',
#  'ec2a',
#  '.',
#  '31p.msg',
#  '@',
#  '150p',
#  "'ll",
#  'rcv',
#  'msgs',
#  'chat',
#  'svc',
#  '.',
#  'free',
#  'hardcore',
#  'services',
#  'text',
#  'go',
#  ':',
#  '69988',
#  'u',
#  'get',
#  'nothing',
#  'u',
#  'must',
#  'age',
#  'verify',
#  'yr',
#  'network',
#  '&',
#  'try',
#  'freemsg',
#  "n't",
#  'replied',
#  'text',
#  '?',
#  "'m",
#  'randy',
#  ',',
#  'sexy',
#  ',',
#  'female',
#  'live',
#  'local',
#  '.',
#  'luv',
#  'hear',
#  'u.',
#  'netcollex',
#  'ltd',
#  '08700621170150p',
#  'per',
#  'msg',
#  'reply',
#  'stop',
#  'end',
#  'customer',
#  'service',
#  'annoncement',
#  '.',
#  'new',
#  'years',
#  'delivery',
#  'waiting',
#  '.',
#  'please',
#  'call',
#  '07046744435',
#  'arrange',
#  'delivery',
#  'winner',
#  'u',
#  'specially',
#  'selected',
#  '2',
#  'receive',
#  'å£1000',
#  'cash',
#  '4',
#  '*',
#  'holiday',
#  '(',
#  'flights',
#  'inc',
#  ')',
#  'speak',
#  'live',
#  'operator',
#  '2',
#  'claim',
#  '0871277810810',
#  '-pls',
#  'stop',
#  'bootydelious',
#  '(',
#  '32/f',
#  ')',
#  'inviting',
#  'friend',
#  '.',
#  'reply',
#  'yes-434',
#  'no-434',
#  'see',
#  ':',
#  'www.sms.ac/u/bootydelious',
#  'stop',
#  '?',
#  'send',
#  'stop',
#  'frnd',
#  '62468',
#  'bangbabes',
#  'ur',
#  'order',
#  'way',
#  '.',
#  'u',
#  'receive',
#  'service',
#  'msg',
#  '2',
#  'download',
#  'ur',
#  'content',
#  '.',
#  'u',
#  ',',
#  'goto',
#  'wap',
#  '.',
#  'bangb',
#  '.',
#  'tv',
#  'ur',
#  'mobile',
#  'internet/service',
#  'menu',
#  'urgent',
#  '!',
#  'trying',
#  'contact',
#  '.',
#  'last',
#  'weekends',
#  'draw',
#  'shows',
#  'å£900',
#  'prize',
#  'guaranteed',
#  '.',
#  'call',
#  '09061701939.',
#  'claim',
#  'code',
#  's89',
#  '.',
#  'valid',
#  '12hrs',
#  'please',
#  'call',
#  'customer',
#  'service',
#  'representative',
#  'freephone',
#  '0808',
#  '145',
#  '4742',
#  '9am-11pm',
#  'guaranteed',
#  'å£1000',
#  'cash',
#  'å£5000',
#  'prize',
#  '!',
#  'unique',
#  'enough',
#  '?',
#  'find',
#  '30th',
#  'august',
#  '.',
#  'www.areyouunique.co.uk',
#  '500',
#  'new',
#  'mobiles',
#  '2004',
#  ',',
#  'must',
#  'go',
#  '!',
#  'txt',
#  ':',
#  'nokia',
#  ':',
#  '89545',
#  '&',
#  'collect',
#  'today',
#  '!',
#  'å£1',
#  'www.4-tc.biz',
#  '2optout',
#  '087187262701.50gbp/mtmsg18',
#  'u',
#  'meet',
#  'ur',
#  'dream',
#  'partner',
#  'soon',
#  '?',
#  'ur',
#  'career',
#  '2',
#  'flyng',
#  'start',
#  '?',
#  '2',
#  'find',
#  'free',
#  ',',
#  'txt',
#  'horo',
#  'followed',
#  'ur',
#  'star',
#  'sign',
#  ',',
#  'e.',
#  'g.',
#  'horo',
#  'aries',
#  'text',
#  '&',
#  'meet',
#  'someone',
#  'sexy',
#  'today',
#  '.',
#  'u',
#  'find',
#  'date',
#  'even',
#  'flirt',
#  'u.',
#  'join',
#  '4',
#  '10p',
#  '.',
#  'reply',
#  'name',
#  '&',
#  'age',
#  'eg',
#  'sam',
#  '25',
#  '.',
#  '18',
#  '-msg',
#  'recd',
#  '@',
#  'thirtyeight',
#  'pence',
#  'u',
#  '447801259231',
#  'secret',
#  'admirer',
#  'looking',
#  '2',
#  'make',
#  'contact',
#  'u-find',
#  'r',
#  '*',
#  'reveal',
#  'thinks',
#  'ur',
#  'special-call',
#  '09058094597',
#  'congratulations',
#  'ur',
#  'awarded',
#  '500',
#  'cd',
#  'vouchers',
#  '125gift',
#  'guaranteed',
#  '&',
#  'free',
#  'entry',
#  '2',
#  '100',
#  'wkly',
#  'draw',
#  'txt',
#  'music',
#  '87066',
#  'tncs',
#  'www.ldew.com1win150ppmx3age16',
#  'tried',
#  'contact',
#  'reply',
#  'offer',
#  'video',
#  'handset',
#  '?',
#  '750',
#  'anytime',
#  'networks',
#  'mins',
#  '?',
#  'unlimited',
#  'text',
#  '?',
#  'camcorder',
#  '?',
#  'reply',
#  'call',
#  '08000930705',
#  'hey',
#  'really',
#  'horny',
#  'want',
#  'chat',
#  'see',
#  'naked',
#  'text',
#  'hot',
#  '69698',
#  'text',
#  'charged',
#  '150pm',
#  'unsubscribe',
#  'text',
#  'stop',
#  '69698',
#  'ur',
#  'ringtone',
#  'service',
#  'changed',
#  '!',
#  '25',
#  'free',
#  'credits',
#  '!',
#  'go',
#  'club4mobiles.com',
#  'choose',
#  'content',
#  '!',
#  'stop',
#  '?',
#  'txt',
#  'club',
#  'stop',
#  '87070',
#  '.',
#  '150p/wk',
#  'club4',
#  'po',
#  'box1146',
#  'mk45',
#  '2wt',
#  'ringtone',
#  'club',
#  ':',
#  'get',
#  'uk',
#  'singles',
#  'chart',
#  'mobile',
#  'week',
#  'choose',
#  'top',
#  'quality',
#  'ringtone',
#  '!',
#  'message',
#  'free',
#  'charge',
#  '.',
#  'hmv',
#  'bonus',
#  'special',
#  '500',
#  'pounds',
#  'genuine',
#  'hmv',
#  'vouchers',
#  '.',
#  'answer',
#  '4',
#  'easy',
#  'questions',
#  '.',
#  'play',
#  '!',
#  'send',
#  'hmv',
#  '86688',
#  'info',
#  ':',
#  'www.100percent-real.com',
#  't-mobile',
#  'customer',
#  'may',
#  'claim',
#  'free',
#  'camera',
#  'phone',
#  'upgrade',
#  '&',
#  'pay',
#  '&',
#  'go',
#  'sim',
#  'card',
#  'loyalty',
#  '.',
#  'call',
#  '0845',
#  '021',
#  '3680.offer',
#  'ends',
#  '28thfeb.t',
#  '&',
#  'c',
#  "'s",
#  'apply',
#  'sms',
#  '.',
#  'ac',
#  'blind',
#  'date',
#  '4u',
#  '!',
#  ':',
#  'rodds1',
#  '21/m',
#  'aberdeen',
#  ',',
#  'united',
#  'kingdom',
#  '.',
#  'check',
#  'http',
#  ':',
#  '//img',
#  '.',
#  'sms',
#  '.',
#  'ac/w/icmb3cktz8r7',
#  '!',
#  '-4',
#  'blind',
#  'dates',
#  'send',
#  'hide',
#  'themob',
#  '>',
#  'check',
#  'newest',
#  'selection',
#  'content',
#  ',',
#  'games',
#  ',',
#  'tones',
#  ',',
#  ...]

# %%
from collections import Counter

# %%
from nltk.stem import PorterStemmer

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\maya rai\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\maya rai\anaconda3\lib\site-packages (from wordcloud) (2.2.2)
# Requirement already satisfied: pillow in c:\users\maya rai\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\maya rai\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\maya rai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\maya rai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\maya rai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\maya rai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\maya rai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\maya rai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\maya rai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\maya rai\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (1.6.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\maya rai\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\Users\Maya Rai\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix

# %%
cv = CountVectorizer()

# %%
X = cv.fit_transform(df['processed']).toarray()
X.shape
# Out:
# (5169, 8607)

# %%
y = df['result'].values
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(5169,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 49)

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train, y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test, y_pred1))
print(confusion_matrix(y_test, y_pred1))
print(precision_score(y_test, y_pred1))
# Out:
# 0.902321083172147
# [[811  88]
#  [ 13 122]]
# 0.580952380952381

# %%
mnb.fit(X_train, y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test, y_pred2))
print(confusion_matrix(y_test, y_pred2))
print(precision_score(y_test, y_pred2))
# Out:
# 0.9748549323017408
# [[880  19]
#  [  7 128]]
# 0.8707482993197279

# %%
bnb.fit(X_train, y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test, y_pred3))
print(confusion_matrix(y_test, y_pred3))
print(precision_score(y_test, y_pred3))
# Out:
# 0.9671179883945842
# [[891   8]
#  [ 26 109]]
# 0.9316239316239316

# %%
tf = TfidfVectorizer()

#transforming the data of processed column
X = tf.fit_transform(df['processed']).toarray()

#storing the values of the 'result' column
y = df['result'].values

#splitting the training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 49)

# %%
gnb.fit(X_train, y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test, y_pred1))
print(confusion_matrix(y_test, y_pred1))
print(precision_score(y_test, y_pred1))
# Out:
# 0.8984526112185687
# [[811  88]
#  [ 17 118]]
# 0.5728155339805825

# %%
mnb.fit(X_train, y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test, y_pred2))
print(confusion_matrix(y_test, y_pred2))
print(precision_score(y_test, y_pred2))
# Out:
# 0.9584139264990329
# [[899   0]
#  [ 43  92]]
# 1.0

# %%
bnb.fit(X_train, y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test, y_pred3))
print(confusion_matrix(y_test, y_pred3))
print(precision_score(y_test, y_pred3))
# Out:
# 0.9671179883945842
# [[891   8]
#  [ 26 109]]
# 0.9316239316239316

# %%
import pickle
pickle.dump(tf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
